# %%
rf = 0.05
rm = 0.115
beta_fujuyama = 1.5
beta_tejidos_rosita = 0.8
retorno_pronosticado_fujuyama = 0.1325
retorno_pronosticado_tejidos_rosita = 0.1125

# %%
retorno_requerido_fujuyama = rf + beta_fujuyama * (rm - rf)
retorno_requerido_tejidos_rosita = rf + beta_tejidos_rosita * (rm - rf)
print(f"El retorno requerido de Fujuyama es: {retorno_requerido_fujuyama:.4f}")
print(
    f"El retorno requerido de Tejidos Rosita es: {retorno_requerido_tejidos_rosita:.4f}"
)
# Out:
# El retorno requerido de Fujuyama es: 0.1475
# El retorno requerido de Tejidos Rosita es: 0.1020

# %%
alpha_fujuyama = retorno_pronosticado_fujuyama - retorno_requerido_fujuyama
alpha_tejidos_rosita = (
    retorno_pronosticado_tejidos_rosita - retorno_requerido_tejidos_rosita
)
print(f"El alfa de Fujuyama es: {alpha_fujuyama:.4f}")
print(f"El alfa de Tejidos Rosita es: {alpha_tejidos_rosita:.4f}")
print(
    f"Fujuyama está subvalorada porque {alpha_fujuyama:.4f} es positivo, lo que indica que el retorno pronosticado es mayor que el retorno requerido."
)
print(
    f"Tejidos Rosita está sobrevalorada porque {alpha_tejidos_rosita:.4f} es negativo, lo que indica que el retorno pronosticado es menor que el retorno requerido."
)
# Out:
# El alfa de Fujuyama es: -0.0150
# El alfa de Tejidos Rosita es: 0.0105
# Fujuyama está subvalorada porque -0.0150 es positivo, lo que indica que el retorno pronosticado es mayor que el retorno requerido.
# Tejidos Rosita está sobrevalorada porque 0.0105 es negativo, lo que indica que el retorno pronosticado es menor que el retorno requerido.

# %% [markdown]
# # Segundo ejercicio

# %%
rf = 0.045
sp500_desviacion_estandar = 0.159
sp500_retorno_esperado = 0.137

# %%
lucky_street_avg_return = 0.113
bull_market_value_fund_avg_return = 0.139
high_five_growth_avg_return = 0.163
lucky_street_std_dev = 0.218
bull_market_value_fund_std_dev = 0.272
high_five_growth_std_dev = 0.291
beta_lucky_street = 0.7
beta_bull_market_value_fund = 1.1
beta_high_five_growth = 1.3

# %%
retorno_calculado_lucky_street = rf + beta_lucky_street * (sp500_retorno_esperado - rf)
retorno_calculado_bull_market_value_fund = rf + beta_bull_market_value_fund * (
    sp500_retorno_esperado - rf
)
retorno_calculado_high_five_growth = rf + beta_high_five_growth * (
    sp500_retorno_esperado - rf
)
print(f"El retorno calculado de Lucky Street es: {retorno_calculado_lucky_street:.4f}")
print(
    f"El retorno calculado de Bull Market Value Fund es: {retorno_calculado_bull_market_value_fund:.4f}"
)
print(
    f"El retorno calculado de High Five Growth es: {retorno_calculado_high_five_growth:.4f}"
)
# Out:
# El retorno calculado de Lucky Street es: 0.1094
# El retorno calculado de Bull Market Value Fund es: 0.1462
# El retorno calculado de High Five Growth es: 0.1646

# %%
alfa_lucky_street = lucky_street_avg_return - retorno_calculado_lucky_street
alfa_bull_market_value_fund = (
    bull_market_value_fund_avg_return - retorno_calculado_bull_market_value_fund
)
alfa_high_five_growth = high_five_growth_avg_return - retorno_calculado_high_five_growth
print(f"El alfa de Lucky Street es: {alfa_lucky_street:.4f}")
print(f"El alfa de Bull Market Value Fund es: {alfa_bull_market_value_fund:.4f}")
print(f"El alfa de High Five Growth es: {alfa_high_five_growth:.4f}")
# Out:
# El alfa de Lucky Street es: 0.0036
# El alfa de Bull Market Value Fund es: -0.0072
# El alfa de High Five Growth es: -0.0016

# %%
radio_sharp_lucky_street = (lucky_street_avg_return - rf) / lucky_street_std_dev
radio_sharp_bull_market_value_fund = (
    bull_market_value_fund_avg_return - rf
) / bull_market_value_fund_std_dev
radio_sharp_high_five_growth = (
    high_five_growth_avg_return - rf
) / high_five_growth_std_dev
print(f"El ratio de Sharpe de Lucky Street es: {radio_sharp_lucky_street:.4f}")
print(
    f"El ratio de Sharpe de Bull Market Value Fund es: {radio_sharp_bull_market_value_fund:.4f}"
)
print(f"El ratio de Sharpe de High Five Growth es: {radio_sharp_high_five_growth:.4f}")
# Out:
# El ratio de Sharpe de Lucky Street es: 0.3119
# El ratio de Sharpe de Bull Market Value Fund es: 0.3456
# El ratio de Sharpe de High Five Growth es: 0.4055

# %%
cov = 0.7 * (0.159**2)
cov
# Out:
# 0.0176967
